# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
house = pd.read_csv('USA_Housing.csv')

# %%
house.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg. Area Income                5000 non-null float64
# Avg. Area House Age             5000 non-null float64
# Avg. Area Number of Rooms       5000 non-null float64
# Avg. Area Number of Bedrooms    5000 non-null float64
# Area Population                 5000 non-null float64
# Price                           5000 non-null float64
# Address                         5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
house.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(house)

# %%
sns.distplot(house['Price'])

# %%
sns.heatmap(house.corr(), annot=True)

# %%
#we want to split data into trainset and testset

# %%
trainset, testset = train_test_split(house, test_size=0.2, random_state = 7)

# %%
print('The trainset contains {} observations'.format(trainset.shape[0]))
# Out:
# The trainset contains 4000 observations

# %%
print('The testset contains {} observations'.format(testset.shape[0]))
# Out:
# The testset contains 1000 observations

# %%
print('The trainset contains {} observations'.format(trainset.shape[0]))
print('\n')
print('The testset contains {} observations'.format(testset.shape[0]))
# Out:
# The trainset contains 4000 observations
#
#
# The testset contains 1000 observations

# %%
print(f"The trainset contains {trainset.shape[0]} observations")
print("\n")
print(f"The trainset contains {trainset.shape[0]} observations")
# Out:
# The trainset contains 4000 observations
#
#
# The trainset contains 4000 observations

# %%
trainset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 2817 to 4271
# Data columns (total 7 columns):
# Avg. Area Income                4000 non-null float64
# Avg. Area House Age             4000 non-null float64
# Avg. Area Number of Rooms       4000 non-null float64
# Avg. Area Number of Bedrooms    4000 non-null float64
# Area Population                 4000 non-null float64
# Price                           4000 non-null float64
# Address                         4000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 250.0+ KB

# %%
testset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 3406 to 3528
# Data columns (total 7 columns):
# Avg. Area Income                1000 non-null float64
# Avg. Area House Age             1000 non-null float64
# Avg. Area Number of Rooms       1000 non-null float64
# Avg. Area Number of Bedrooms    1000 non-null float64
# Area Population                 1000 non-null float64
# Price                           1000 non-null float64
# Address                         1000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 62.5+ KB

# %%
trainset.head()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2817      69446.455214             6.755067                   8.500982
# 1714      46517.175275             6.326333                   7.570723
# 4418      73047.325813             6.458335                   7.518636
# 3634      77779.244941             6.847532                   6.315602
# 4945      52361.247972             5.350466                   6.595070
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 2817                          6.29     47025.183677  1.738788e+06
# 1714                          5.01     26452.367894  6.651601e+05
# 4418                          6.04     47053.459064  1.703880e+06
# 3634                          3.18     46402.254150  1.597153e+06
# 4945                          3.05     48661.989744  9.712002e+05
#
#                                                 Address
# 2817  68483 Jones Overpass Apt. 040\nPort April, OH ...
# ...

# %% [markdown]
# # EDA

# %%
sns.set_style('whitegrid')

# %%
sns.distplot(trainset['Price'], bins= 20)

# %%
trainset['Price'].mean()
# Out:
# 1232367.9536083806

# %%
trainset['Price'].median()
# Out:
# 1232540.9161864188

# %%
sns.jointplot(x = 'Avg. Area Income', y = 'Price', data =trainset, kind= 'hex' )

# %%
trainset.head()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2817      69446.455214             6.755067                   8.500982
# 1714      46517.175275             6.326333                   7.570723
# 4418      73047.325813             6.458335                   7.518636
# 3634      77779.244941             6.847532                   6.315602
# 4945      52361.247972             5.350466                   6.595070
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 2817                          6.29     47025.183677  1.738788e+06
# 1714                          5.01     26452.367894  6.651601e+05
# 4418                          6.04     47053.459064  1.703880e+06
# 3634                          3.18     46402.254150  1.597153e+06
# 4945                          3.05     48661.989744  9.712002e+05
#
#                                                 Address
# 2817  68483 Jones Overpass Apt. 040\nPort April, OH ...
# ...

# %%
sns.pairplot(trainset)

# %%
#make a correlation plot
trainset_corr = trainset.corr()

# %%
sns.heatmap(trainset_corr, annot = True)

# %%
#drop address because it is not important to the model to be created
trainset.drop('Address', inplace = True, axis = 1)
testset.drop('Address', inplace = True, axis = 1)
# Out:
# C:\Users\iDAFAdmin\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# # Model Creation and Evaluation

# %% [markdown]
# y = mx + c
# y = m1x1 + m2x2 + ... + mnxn +c
# 1. x is our independent variable
# 2. y is our dependent variable

# %%
# train_test_split()

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c55e8f346529> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)
#
# NameError: name 'X' is not defined

# %%
#creating dependent and independent variables 

X = trainset.drop('Price', axis = 1)
y = trainset['Price']

# %%
#create an object for the model 

lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lr.intercept_)
# Out:
# -2648948.6335659055

# %%
lr.coef_
# Out:
# array([2.16071992e+01, 1.66225455e+05, 1.21176334e+05, 1.91088009e+03,
#        1.52603049e+01])

# %%
prediction = lr.predict(testset.drop('Price', axis = 1))

# %%
testset.drop('Price', axis = 1)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3406      56851.083124             6.712027                   7.056322
# 757       87506.731974             5.430800                   4.947302
# 3624      76023.748497             4.974834                   6.913990
# 4544      82732.981114             5.332712                   6.198476
# 3235      64780.875832             7.313804                   6.110466
# ...                ...                  ...                        ...
# 4630      72791.270536             5.375329                   5.441100
# 4730      64795.527101             5.303131                   6.612386
# 1918      64989.783962             5.162645                   7.462080
# 2481      65948.918141             4.007017                   8.854370
# 3528      56879.823232             7.814890                   7.400685
#
#       Avg. Area Number of Bedrooms  Area Population
# 3406                          4.44     37438.936041
# ...

# %%
#checking for the r2_score value

print('R2_score value is {}'.format(r2_score(testset['Price'],prediction)))
# Out:
# R2_score value is 0.9097713553763818

# %%
sns.scatterplot(x='Price', y= 'Avg. Area Income', data = trainset)

# %%
sns.lmplot(x='Price', y= 'Avg. Area Income', data = trainset)

# %%
trainset.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %% [markdown]
# ###Things you can infer from a scatterplot
#
# 1. Relationship between variables - positive or negative correlation
# 2. Check for Outliers
# 3. Assume if the slope i.e m is either positive or negative

# %% [markdown]
# # SCALING FEATURES

# %%
trainset.head()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2817      69446.455214             6.755067                   8.500982
# 1714      46517.175275             6.326333                   7.570723
# 4418      73047.325813             6.458335                   7.518636
# 3634      77779.244941             6.847532                   6.315602
# 4945      52361.247972             5.350466                   6.595070
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# 2817                          6.29     47025.183677  1.738788e+06
# 1714                          5.01     26452.367894  6.651601e+05
# 4418                          6.04     47053.459064  1.703880e+06
# 3634                          3.18     46402.254150  1.597153e+06
# 4945                          3.05     48661.989744  9.712002e+05

# %%
#standard scaler

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %% [markdown]
# scaled_feature = (x-xhat)/sd

# %%
# scaled_feature = (69446.455214 - trainset['Avg. Area Income'].mean())/trainset['Avg. Area Income'].std()

# scaled_feature

# %%
X_scaled = scaler.fit_transform(X)
test_scaled = scaler.transform(testset.drop('Price', axis = 1))

# %%
lr_1 = LinearRegression()
lr_1.fit(X_scaled, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction = lr_1.predict(test_scaled)

# %%
print(f"The R2_score value is {r2_score(testset['Price'],prediction)}")
# Out:
# The R2_score value is 0.90977135537639

# %%
plt.scatter(prediction,testset['Price'])

# %%
#root-mean-square-error
from sklearn.metrics import mean_squared_error

print(f"The mean_squared_error of the model is {mean_squared_error(prediction,testset['Price'])}")
print("\n")
print(f"The root_mean_squared_error of the model is {np.sqrt(mean_squared_error(prediction,testset['Price']))}")
# Out:
# The mean_squared_error of the model is 10477347847.899694
#
#
# The root_mean_squared_error of the model is 102358.91679721749

# %% [markdown]
# # Using Ordinary Least Squares(OLS)

# %% [markdown]
# y = mx + c

# %%
import statsmodels.api as sm

# %%
#adding constant tk the independent variable 

X_const = sm.add_constant(X)
test_const = sm.add_constant(testset.drop('Price', axis=1))
# Out:
# C:\Users\iDAFAdmin\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
model = sm.OLS(y, X_const).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     9173.
# Date:                Mon, 09 Aug 2021   Prob (F-statistic):               0.00
# Time:                        17:16:10   Log-Likelihood:                -51759.
# No. Observations:                4000   AIC:                         1.035e+05
# Df Residuals:                    3994   BIC:                         1.036e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
#drop Avg. number of bedrooms since its > 0.05

#Steph's 

#X.drop('Avg. Number of Bedrooms', axis=1, inplace= True)

# %%
#mine

# X_const = sm.add_constant(trainset.drop('Avg. Area Number of Bedrooms', axis=1)
# test_const = sm.add_constant(testset.drop('Price', axis=1))

# %%
X.drop('Avg. Area Number of Bedrooms', axis=1, inplace= True)
X_const = sm.add_constant(X)
test_const = sm.add_constant(testset.drop('Price', axis=1))

# %%
model = sm.OLS(y, X_const).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                 1.146e+04
# Date:                Mon, 09 Aug 2021   Prob (F-statistic):               0.00
# Time:                        17:19:31   Log-Likelihood:                -51760.
# No. Observations:                4000   AIC:                         1.035e+05
# Df Residuals:                    3995   BIC:                         1.036e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...
